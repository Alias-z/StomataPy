# %% [markdown]
# # **StomataPy Colab demo**
#
# Autor: Hongyuan from Santelia Lab at ETH Zurich
#
# Contact: hongyuan.zhang@usys.ethz.ch

# %% [markdown]
# ## 1. Install StomataPy

# %%
# %%capture
# !git clone --recursive https://github.com/Alias-z/StomataPy.git
# %cd /content/StomataPy
# !uv venv venv --python 3.10
# !uv sync
# !uv pip install torch==2.1.1+cu118 torchvision==0.16.1+cu118 torchaudio==2.1.1+cu118 --extra-index-url https://download.pytorch.org/whl/cu118 --python /content/StomataPy/.venv/bin/python
# !uv run --python /content/StomataPy/.venv/bin/python -m mim install mmengine==0.10.4 mmcv==2.1.0 mmpretrain --trusted-host download.openmmlab.com --find-links https://download.openmmlab.com/mmcv/dist/cu118/torch2.1.0/index.html
# !uv pip install -e ./sam-hq -e ./mmsegmentation -e ./mmdetection --no-build-isolation --python /content/StomataPy/.venv/bin/python
# !uv pip install numpy==1.26.4 xformers==0.0.23 --python /content/StomataPy/.venv/bin/python

# %% [markdown]
# ## 2. Download model weights

# %%
# %%capture
from google.colab import userdata
hf_token = userdata.get('hf_token')
# !export HF_TOKEN="$hf_token"
# !HF_HUB_ETAG_TIMEOUT=50000
# !huggingface-cli login --token "$hf_token"
# !huggingface-cli download aliasz/StomataPy400K-Models --local-dir ./Checkpoints --force-download

# %% [markdown]
# ## [Recommended] Mount to Google Drive exchange data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 3. Run StomataPy

# %%
#@title Model Settings

#@markdown  **Mandatory parameters** (scale in pixels / micrometer)
aim = 'Desnity' #@param ['Desnity', 'Aperture', 'Starch']
input_dir = "asserts/sample_images" #@param {type: 'string'}
output_dir = "(!!! only for starch inference)" #@param {type: 'string'}
scale = 4.3 #@param {type: 'number'}
denisty_model = 'StomataPy400K_density_betatest_n387' #@param ['StomataPy400K_denisty_24185', 'StomataPy400K_density_betatest_n387', 'Heidelberg_trichome_testset4']

#@markdown  **Optional (Do not modify if you are not sure)**

use_sahi = True #@param {type:'boolean'}
stack_input = False #@param {type:'boolean'}
check_straight_edges = False #@param {type:'boolean'}
straight_line_threshold = 100 #@param {type:'slider', min:0, max:500, step:10}

# !sudo uv run --python /content/StomataPy/.venv/bin/python -m main --aim "{aim}" --input_dir "{input_dir}" --output_dir "{output_dir}" --scale {scale} --denisty_model "{denisty_model}" --use_sahi {use_sahi} --stack_input {stack_input} --check_straight_edges {check_straight_edges} --straight_line_threshold {straight_line_threshold}
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Namespace(aim='Desnity', input_dir='asserts/sample_images', scale=4.3, denisty_model='StomataPy400K_density_betatest_n387', use_sahi='True', stack_input='False', check_straight_edges='False', show_prediction='False', straight_line_threshold=100.0)
# Loads checkpoint by local backend from path: Checkpoints/StomataPy400K_aperture_512/dinov2_segmentor.pth
# Loads checkpoint by local backend from path: Checkpoints/StomataPy400K_density_betatest_n387/dinov2_detector.pth
# ...

# %% [markdown]
# ## download your results

# %%
# !zip -r my_images.zip "{input_dir}"
# Out:
#   adding: asserts/sample_images/ (stored 0%)
#   adding: asserts/sample_images/M. virginiana Fetter2019 Magnolia_virginiana_USMALL_01_A1_DIC_stack.jpg (deflated 1%)
#   adding: asserts/sample_images/G. biloba Fetter2019 Gingko_biloba_RSB_1640_Redo_A_L_Spot3_200x50_grid_019.json (deflated 79%)
#   adding: asserts/sample_images/C. rubiginosa Fetter2019 cropped_MLC_FLMNH00413_Sapindaceae_Cupania_rubiginosa_grouped_gray_400dpi.json (deflated 82%)
#   adding: asserts/sample_images/Z. mays Xie2021 17RIL_319_L1_1.tif (deflated 0%)
#   adding: asserts/sample_images/A. aurea Vofely2019 CellImages 7-23-400x-1-04.tif (deflated 28%)
#   adding: asserts/sample_images/C. rubiginosa Fetter2019 cropped_MLC_FLMNH00413_Sapindaceae_Cupania_rubiginosa_grouped_gray_400dpi.jpg (deflated 6%)
#   adding: asserts/sample_images/C. sativus Hongyuan Trial 2 Replicate 3 EON-2hRL IM230611 8.json (deflated 81%)
#   adding: asserts/sample_images/T. aestivum Sun2021 jpg 03056.jpg (deflated 0%)
# ...
